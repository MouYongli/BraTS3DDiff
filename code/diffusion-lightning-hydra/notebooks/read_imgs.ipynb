# %%
from matplotlib import pyplot as plt
import numpy as np

path = '/home/sanyal/DATA/diffusion-lightning-hydra-out/logs/eval/runs/2024-05-01_10-19-18/samples_100x32x32x3.npz'
data = np.load(path)['arr_0'][19]
plt.imshow(data, interpolation='nearest')
plt.show()

# %%
np.load(path)['arr_1'][9]
# Out:
# 9
